# %% [markdown]
# # Tut-20 : CodeBasics
# # Bias vs Variance in ML

# %% [markdown]
# let us consider two scenarios ,where two different set of train-test split has occured :
#
# ![image.png](attachment:image.png)
#
# there is high variance in test-error

# %% [markdown]
# here is an example of low variance , but high Bias.
# Bias is measure of how accurate ur trained dataset is captured :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# This is an ideal case :
#
#    ![image.png](attachment:image.png)

# %% [markdown]
# it is likely that whenever you get a :
#
# overfit - It has high Variance , low Bias
# underfit - It has low Variance , High Bias
# balancedfit - It has low variance , low Bias
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A simple Representation of Variance and Bias :
#     consider the center as 'Truth' and diamonds as 'prediction'
#
#    ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
